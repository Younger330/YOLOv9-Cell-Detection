# %%
import argparse 
import os
from pathlib import Path
import torch
import numpy as np
import cv2
from models.common import DetectMultiBackend

# %%
def resize_with_padding(image, target_size=1024):
    h, w, _ = image.shape
    ratio = target_size / max(h, w)
    new_h, new_w = int(h * ratio), int(w * ratio)
    image_resized = cv2.resize(image, (new_w, new_h))
    
    top_padding = (target_size - new_h) // 2
    bottom_padding = target_size - new_h - top_padding
    left_padding = (target_size - new_w) // 2
    right_padding = target_size - new_w - left_padding

    padded_image = cv2.copyMakeBorder(image_resized, top_padding, bottom_padding, 
                                      left_padding, right_padding, cv2.BORDER_CONSTANT, value=(0, 0, 0))
    return padded_image

# %%
def load_image(img_path, device):
    image = cv2.imread(img_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_resized = resize_with_padding(image, target_size=1024)
    img_tensor = torch.from_numpy(image_resized).float().permute(2, 0, 1).unsqueeze(0) / 255.0
    img_tensor = img_tensor.to(device)

    return img_tensor

# %%
def load_model(weights, device, out_channels=1):
    model = DetectMultiBackend(weights, device=device)
    model.eval()
    return model

# %%
weights = 'runs/train/BMblood/CP-yolov9-c/weights/best.pt'
img_path = '../data/BMBlood/IN/val/images/987.jpg'
save_path = 'runs/heatmap/987_heatmap.png'
device = 'cuda:1'

# %%
device = torch.device(device)
model = load_model(weights, device)
img = load_image(img_path, device)
# Out:
# Fusing layers...
# yolov9-c summary: 604 layers, 50790678 parameters, 0 gradients, 237.1 GFLOPs

# %%
# 查看model.38的子模型结构，使用 named_modules() 打印层名称和路径

'''
model.38.cv2是一个container，是ModuleList，不适合作为钩子
'''

print("\nSubmodules under model.38:")
for name, module in model.model.named_modules():
    if name.startswith("model.38"):
        print(f"{name}: {type(module)}")
# Out:
# Submodules under model.38:
# model.38: <class 'models.yolo.DualDDetect'>
# model.38.cv2: <class 'torch.nn.modules.container.ModuleList'>
# model.38.cv2.0: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv2.0.0: <class 'models.common.Conv'>
# model.38.cv2.0.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv2.0.1: <class 'models.common.Conv'>
# model.38.cv2.0.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv2.0.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv2.1: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv2.1.0: <class 'models.common.Conv'>
# model.38.cv2.1.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv2.1.1: <class 'models.common.Conv'>
# model.38.cv2.1.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv2.1.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv2.2: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv2.2.0: <class 'models.common.Conv'>
# model.38.cv2.2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv2.2.1: <class 'models.common.Conv'>
# model.38.cv2.2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv2.2.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3: <class 'torch.nn.modules.container.ModuleList'>
# model.38.cv3.0: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv3.0.0: <class 'models.common.Conv'>
# model.38.cv3.0.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3.0.1: <class 'models.common.Conv'>
# model.38.cv3.0.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3.0.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3.1: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv3.1.0: <class 'models.common.Conv'>
# model.38.cv3.1.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3.1.1: <class 'models.common.Conv'>
# model.38.cv3.1.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3.1.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3.2: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv3.2.0: <class 'models.common.Conv'>
# model.38.cv3.2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3.2.1: <class 'models.common.Conv'>
# model.38.cv3.2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv3.2.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4: <class 'torch.nn.modules.container.ModuleList'>
# model.38.cv4.0: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv4.0.0: <class 'models.common.Conv'>
# model.38.cv4.0.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4.0.1: <class 'models.common.Conv'>
# model.38.cv4.0.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4.0.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4.1: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv4.1.0: <class 'models.common.Conv'>
# model.38.cv4.1.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4.1.1: <class 'models.common.Conv'>
# model.38.cv4.1.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4.1.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4.2: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv4.2.0: <class 'models.common.Conv'>
# model.38.cv4.2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4.2.1: <class 'models.common.Conv'>
# model.38.cv4.2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv4.2.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5: <class 'torch.nn.modules.container.ModuleList'>
# model.38.cv5.0: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv5.0.0: <class 'models.common.Conv'>
# model.38.cv5.0.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5.0.1: <class 'models.common.Conv'>
# model.38.cv5.0.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5.0.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5.1: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv5.1.0: <class 'models.common.Conv'>
# model.38.cv5.1.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5.1.1: <class 'models.common.Conv'>
# model.38.cv5.1.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5.1.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5.2: <class 'torch.nn.modules.container.Sequential'>
# model.38.cv5.2.0: <class 'models.common.Conv'>
# model.38.cv5.2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5.2.1: <class 'models.common.Conv'>
# model.38.cv5.2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.cv5.2.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.dfl: <class 'models.common.DFL'>
# model.38.dfl.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.38.dfl2: <class 'models.common.DFL'>
# model.38.dfl2.conv: <class 'torch.nn.modules.conv.Conv2d'>

# %%
print(model.model)
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Silence()
#     (1): Conv(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): SiLU(inplace=True)
#     )
#     (2): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): SiLU(inplace=True)
#     )
#     (3): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (4): ADown(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (5): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (6): ADown(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (7): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (8): ADown(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (9): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (10): SPPELAN(
#       (cv1): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): SP(
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (cv3): SP(
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (cv4): SP(
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (cv5): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (11): Upsample(scale_factor=2.0, mode='nearest')
#     (12): Concat()
#     (13): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (14): Upsample(scale_factor=2.0, mode='nearest')
#     (15): Concat()
#     (16): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (17): ADown(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (18): Concat()
#     (19): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (20): ADown(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (21): Concat()
#     (22): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (23): CBLinear(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (24): CBLinear(
#       (conv): Conv2d(512, 768, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (25): CBLinear(
#       (conv): Conv2d(512, 1280, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (26): Conv(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): SiLU(inplace=True)
#     )
#     (27): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (act): SiLU(inplace=True)
#     )
#     (28): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (29): ADown(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (30): CBFuse()
#     (31): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (32): ADown(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (33): CBFuse()
#     (34): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (35): ADown(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (36): CBFuse()
#     (37): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv3): Sequential(
#         (0): RepNCSP(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): RepNBottleneck(
#               (cv1): RepConvN(
#                 (act): SiLU(inplace=True)
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (cv4): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#     )
#     (38): DualDDetect(
#       (cv2): ModuleList(
#         (0-2): 3 x Sequential(
#           (0): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), groups=4)
#         )
#       )
#       (cv3): ModuleList(
#         (0-2): 3 x Sequential(
#           (0): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(512, 41, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (cv4): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), groups=4)
#         )
#         (1-2): 2 x Sequential(
#           (0): Conv(
#             (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), groups=4)
#         )
#       )
#       (cv5): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(256, 41, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1-2): 2 x Sequential(
#           (0): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(256, 41, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (dfl): DFL(
#         (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (dfl2): DFL(
#         (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
# )

# %% [markdown]
#  查看22层主干网络的结构

# %%
import torch
from models.yolo import Model

# %%
device = torch.device("cuda:1")
cfg = "./data/gelan-c.yaml"
model = Model(cfg, ch=3, nc=41, anchors=3)
#model = model.half()
model = model.to(device)
_ = model.eval()
ckpt = torch.load('runs/train/BMblood/CP-yolov9-c/weights/best.pt', map_location='cuda:1')
model.names = ckpt['model'].names
model.nc = ckpt['model'].nc
# Out:
# Overriding model.yaml anchors with anchors=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5522251  models.yolo.DDetect                     [41, [256, 512, 512]]
# gelan-c summary: 621 layers, 25468683 parameters, 25468667 gradients, 103.3 GFLOPs

# %%
print(model.model)
# Out:
# Sequential(
#   (0): Conv(
#     (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (1): Conv(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (2): RepNCSPELAN4(
#     (cv1): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv3): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv4): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (3): ADown(
#     (cv1): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (4): RepNCSPELAN4(
#     (cv1): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv3): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv4): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (5): ADown(
#     (cv1): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (6): RepNCSPELAN4(
#     (cv1): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv3): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv4): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (7): ADown(
#     (cv1): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (8): RepNCSPELAN4(
#     (cv1): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv3): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv4): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (9): SPPELAN(
#     (cv1): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): SP(
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (cv3): SP(
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (cv4): SP(
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (cv5): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (10): Upsample(scale_factor=2.0, mode='nearest')
#   (11): Concat()
#   (12): RepNCSPELAN4(
#     (cv1): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv3): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv4): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (13): Upsample(scale_factor=2.0, mode='nearest')
#   (14): Concat()
#   (15): RepNCSPELAN4(
#     (cv1): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv3): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv4): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (16): ADown(
#     (cv1): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (17): Concat()
#   (18): RepNCSPELAN4(
#     (cv1): Conv(
#       (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv3): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv4): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (19): ADown(
#     (cv1): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (20): Concat()
#   (21): RepNCSPELAN4(
#     (cv1): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv3): Sequential(
#       (0): RepNCSP(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): RepNBottleneck(
#             (cv1): RepConvN(
#               (act): SiLU(inplace=True)
#               (conv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (conv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (cv4): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#   )
#   (22): DDetect(
#     (cv2): ModuleList(
#       (0): Sequential(
#         (0): Conv(
#           (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), groups=4)
#       )
#       (1-2): 2 x Sequential(
#         (0): Conv(
#           (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), groups=4)
#       )
#     )
#     (cv3): ModuleList(
#       (0): Sequential(
#         (0): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(256, 41, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1-2): 2 x Sequential(
#         (0): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (2): Conv2d(256, 41, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (dfl): DFL(
#       (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
# )

# %%
print("\nSubmodules under model.22:")
for name, module in model.named_modules():
    if name.startswith("model.22"):
        print(f"{name}: {type(module)}")
# Out:
# Submodules under model.22:
# model.22: <class 'models.yolo.DDetect'>
# model.22.cv2: <class 'torch.nn.modules.container.ModuleList'>
# model.22.cv2.0: <class 'torch.nn.modules.container.Sequential'>
# model.22.cv2.0.0: <class 'models.common.Conv'>
# model.22.cv2.0.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv2.0.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv2.0.1: <class 'models.common.Conv'>
# model.22.cv2.0.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv2.0.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv2.0.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv2.1: <class 'torch.nn.modules.container.Sequential'>
# model.22.cv2.1.0: <class 'models.common.Conv'>
# model.22.cv2.1.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv2.1.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv2.1.1: <class 'models.common.Conv'>
# model.22.cv2.1.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv2.1.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv2.1.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv2.2: <class 'torch.nn.modules.container.Sequential'>
# model.22.cv2.2.0: <class 'models.common.Conv'>
# model.22.cv2.2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv2.2.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv2.2.1: <class 'models.common.Conv'>
# model.22.cv2.2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv2.2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv2.2.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3: <class 'torch.nn.modules.container.ModuleList'>
# model.22.cv3.0: <class 'torch.nn.modules.container.Sequential'>
# model.22.cv3.0.0: <class 'models.common.Conv'>
# model.22.cv3.0.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3.0.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv3.0.1: <class 'models.common.Conv'>
# model.22.cv3.0.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3.0.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv3.0.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3.1: <class 'torch.nn.modules.container.Sequential'>
# model.22.cv3.1.0: <class 'models.common.Conv'>
# model.22.cv3.1.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3.1.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv3.1.1: <class 'models.common.Conv'>
# model.22.cv3.1.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3.1.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv3.1.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3.2: <class 'torch.nn.modules.container.Sequential'>
# model.22.cv3.2.0: <class 'models.common.Conv'>
# model.22.cv3.2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3.2.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv3.2.1: <class 'models.common.Conv'>
# model.22.cv3.2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.cv3.2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# model.22.cv3.2.2: <class 'torch.nn.modules.conv.Conv2d'>
# model.22.dfl: <class 'models.common.DFL'>
# model.22.dfl.conv: <class 'torch.nn.modules.conv.Conv2d'>

# %%
print("\nSubmodules under model:")
for name, module in model.model.named_modules():
    print(f"{name}: {type(module)}")
# Out:
# Submodules under model:
# : <class 'torch.nn.modules.container.Sequential'>
# 0: <class 'models.common.Conv'>
# 0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 0.act: <class 'torch.nn.modules.activation.SiLU'>
# 1: <class 'models.common.Conv'>
# 1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2: <class 'models.common.RepNCSPELAN4'>
# 2.cv1: <class 'models.common.Conv'>
# 2.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv2: <class 'torch.nn.modules.container.Sequential'>
# 2.cv2.0: <class 'models.common.RepNCSP'>
# 2.cv2.0.cv1: <class 'models.common.Conv'>
# 2.cv2.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv2.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv2.0.cv2: <class 'models.common.Conv'>
# 2.cv2.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv2.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv2.0.cv3: <class 'models.common.Conv'>
# 2.cv2.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv2.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv2.0.m: <class 'torch.nn.modules.container.Sequential'>
# 2.cv2.0.m.0: <class 'models.common.RepNBottleneck'>
# 2.cv2.0.m.0.cv1: <class 'models.common.RepConvN'>
# 2.cv2.0.m.0.cv1.act: <class 'torch.nn.modules.activation.SiLU'>
# 2.cv2.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 2.cv2.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv2.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv2.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 2.cv2.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 2.cv2.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv2.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv2.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 2.cv2.0.m.0.cv2: <class 'models.common.Conv'>
# 2.cv2.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv2.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv2.1: <class 'models.common.Conv'>
# 2.cv2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv3: <class 'torch.nn.modules.container.Sequential'>
# 2.cv3.0: <class 'models.common.RepNCSP'>
# 2.cv3.0.cv1: <class 'models.common.Conv'>
# 2.cv3.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv3.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv3.0.cv2: <class 'models.common.Conv'>
# 2.cv3.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv3.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv3.0.cv3: <class 'models.common.Conv'>
# 2.cv3.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv3.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv3.0.m: <class 'torch.nn.modules.container.Sequential'>
# 2.cv3.0.m.0: <class 'models.common.RepNBottleneck'>
# 2.cv3.0.m.0.cv1: <class 'models.common.RepConvN'>
# 2.cv3.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 2.cv3.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv3.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv3.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 2.cv3.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 2.cv3.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv3.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv3.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 2.cv3.0.m.0.cv2: <class 'models.common.Conv'>
# 2.cv3.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv3.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv3.1: <class 'models.common.Conv'>
# 2.cv3.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv3.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 2.cv4: <class 'models.common.Conv'>
# 2.cv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 2.cv4.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 3: <class 'models.common.ADown'>
# 3.cv1: <class 'models.common.Conv'>
# 3.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 3.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 3.cv2: <class 'models.common.Conv'>
# 3.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 3.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4: <class 'models.common.RepNCSPELAN4'>
# 4.cv1: <class 'models.common.Conv'>
# 4.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv2: <class 'torch.nn.modules.container.Sequential'>
# 4.cv2.0: <class 'models.common.RepNCSP'>
# 4.cv2.0.cv1: <class 'models.common.Conv'>
# 4.cv2.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv2.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv2.0.cv2: <class 'models.common.Conv'>
# 4.cv2.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv2.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv2.0.cv3: <class 'models.common.Conv'>
# 4.cv2.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv2.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv2.0.m: <class 'torch.nn.modules.container.Sequential'>
# 4.cv2.0.m.0: <class 'models.common.RepNBottleneck'>
# 4.cv2.0.m.0.cv1: <class 'models.common.RepConvN'>
# 4.cv2.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 4.cv2.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv2.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv2.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 4.cv2.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 4.cv2.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv2.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv2.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 4.cv2.0.m.0.cv2: <class 'models.common.Conv'>
# 4.cv2.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv2.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv2.1: <class 'models.common.Conv'>
# 4.cv2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv3: <class 'torch.nn.modules.container.Sequential'>
# 4.cv3.0: <class 'models.common.RepNCSP'>
# 4.cv3.0.cv1: <class 'models.common.Conv'>
# 4.cv3.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv3.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv3.0.cv2: <class 'models.common.Conv'>
# 4.cv3.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv3.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv3.0.cv3: <class 'models.common.Conv'>
# 4.cv3.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv3.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv3.0.m: <class 'torch.nn.modules.container.Sequential'>
# 4.cv3.0.m.0: <class 'models.common.RepNBottleneck'>
# 4.cv3.0.m.0.cv1: <class 'models.common.RepConvN'>
# 4.cv3.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 4.cv3.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv3.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv3.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 4.cv3.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 4.cv3.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv3.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv3.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 4.cv3.0.m.0.cv2: <class 'models.common.Conv'>
# 4.cv3.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv3.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv3.1: <class 'models.common.Conv'>
# 4.cv3.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv3.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 4.cv4: <class 'models.common.Conv'>
# 4.cv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 4.cv4.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 5: <class 'models.common.ADown'>
# 5.cv1: <class 'models.common.Conv'>
# 5.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 5.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 5.cv2: <class 'models.common.Conv'>
# 5.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 5.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6: <class 'models.common.RepNCSPELAN4'>
# 6.cv1: <class 'models.common.Conv'>
# 6.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv2: <class 'torch.nn.modules.container.Sequential'>
# 6.cv2.0: <class 'models.common.RepNCSP'>
# 6.cv2.0.cv1: <class 'models.common.Conv'>
# 6.cv2.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv2.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv2.0.cv2: <class 'models.common.Conv'>
# 6.cv2.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv2.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv2.0.cv3: <class 'models.common.Conv'>
# 6.cv2.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv2.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv2.0.m: <class 'torch.nn.modules.container.Sequential'>
# 6.cv2.0.m.0: <class 'models.common.RepNBottleneck'>
# 6.cv2.0.m.0.cv1: <class 'models.common.RepConvN'>
# 6.cv2.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 6.cv2.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv2.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv2.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 6.cv2.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 6.cv2.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv2.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv2.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 6.cv2.0.m.0.cv2: <class 'models.common.Conv'>
# 6.cv2.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv2.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv2.1: <class 'models.common.Conv'>
# 6.cv2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv3: <class 'torch.nn.modules.container.Sequential'>
# 6.cv3.0: <class 'models.common.RepNCSP'>
# 6.cv3.0.cv1: <class 'models.common.Conv'>
# 6.cv3.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv3.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv3.0.cv2: <class 'models.common.Conv'>
# 6.cv3.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv3.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv3.0.cv3: <class 'models.common.Conv'>
# 6.cv3.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv3.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv3.0.m: <class 'torch.nn.modules.container.Sequential'>
# 6.cv3.0.m.0: <class 'models.common.RepNBottleneck'>
# 6.cv3.0.m.0.cv1: <class 'models.common.RepConvN'>
# 6.cv3.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 6.cv3.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv3.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv3.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 6.cv3.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 6.cv3.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv3.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv3.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 6.cv3.0.m.0.cv2: <class 'models.common.Conv'>
# 6.cv3.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv3.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv3.1: <class 'models.common.Conv'>
# 6.cv3.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv3.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 6.cv4: <class 'models.common.Conv'>
# 6.cv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 6.cv4.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 7: <class 'models.common.ADown'>
# 7.cv1: <class 'models.common.Conv'>
# 7.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 7.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 7.cv2: <class 'models.common.Conv'>
# 7.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 7.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8: <class 'models.common.RepNCSPELAN4'>
# 8.cv1: <class 'models.common.Conv'>
# 8.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv2: <class 'torch.nn.modules.container.Sequential'>
# 8.cv2.0: <class 'models.common.RepNCSP'>
# 8.cv2.0.cv1: <class 'models.common.Conv'>
# 8.cv2.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv2.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv2.0.cv2: <class 'models.common.Conv'>
# 8.cv2.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv2.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv2.0.cv3: <class 'models.common.Conv'>
# 8.cv2.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv2.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv2.0.m: <class 'torch.nn.modules.container.Sequential'>
# 8.cv2.0.m.0: <class 'models.common.RepNBottleneck'>
# 8.cv2.0.m.0.cv1: <class 'models.common.RepConvN'>
# 8.cv2.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 8.cv2.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv2.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv2.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 8.cv2.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 8.cv2.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv2.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv2.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 8.cv2.0.m.0.cv2: <class 'models.common.Conv'>
# 8.cv2.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv2.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv2.1: <class 'models.common.Conv'>
# 8.cv2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv3: <class 'torch.nn.modules.container.Sequential'>
# 8.cv3.0: <class 'models.common.RepNCSP'>
# 8.cv3.0.cv1: <class 'models.common.Conv'>
# 8.cv3.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv3.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv3.0.cv2: <class 'models.common.Conv'>
# 8.cv3.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv3.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv3.0.cv3: <class 'models.common.Conv'>
# 8.cv3.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv3.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv3.0.m: <class 'torch.nn.modules.container.Sequential'>
# 8.cv3.0.m.0: <class 'models.common.RepNBottleneck'>
# 8.cv3.0.m.0.cv1: <class 'models.common.RepConvN'>
# 8.cv3.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 8.cv3.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv3.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv3.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 8.cv3.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 8.cv3.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv3.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv3.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 8.cv3.0.m.0.cv2: <class 'models.common.Conv'>
# 8.cv3.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv3.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv3.1: <class 'models.common.Conv'>
# 8.cv3.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv3.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 8.cv4: <class 'models.common.Conv'>
# 8.cv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 8.cv4.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 9: <class 'models.common.SPPELAN'>
# 9.cv1: <class 'models.common.Conv'>
# 9.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 9.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 9.cv2: <class 'models.common.SP'>
# 9.cv2.m: <class 'torch.nn.modules.pooling.MaxPool2d'>
# 9.cv3: <class 'models.common.SP'>
# 9.cv3.m: <class 'torch.nn.modules.pooling.MaxPool2d'>
# 9.cv4: <class 'models.common.SP'>
# 9.cv4.m: <class 'torch.nn.modules.pooling.MaxPool2d'>
# 9.cv5: <class 'models.common.Conv'>
# 9.cv5.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 9.cv5.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 10: <class 'torch.nn.modules.upsampling.Upsample'>
# 11: <class 'models.common.Concat'>
# 12: <class 'models.common.RepNCSPELAN4'>
# 12.cv1: <class 'models.common.Conv'>
# 12.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv2: <class 'torch.nn.modules.container.Sequential'>
# 12.cv2.0: <class 'models.common.RepNCSP'>
# 12.cv2.0.cv1: <class 'models.common.Conv'>
# 12.cv2.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv2.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv2.0.cv2: <class 'models.common.Conv'>
# 12.cv2.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv2.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv2.0.cv3: <class 'models.common.Conv'>
# 12.cv2.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv2.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv2.0.m: <class 'torch.nn.modules.container.Sequential'>
# 12.cv2.0.m.0: <class 'models.common.RepNBottleneck'>
# 12.cv2.0.m.0.cv1: <class 'models.common.RepConvN'>
# 12.cv2.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 12.cv2.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv2.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv2.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 12.cv2.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 12.cv2.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv2.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv2.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 12.cv2.0.m.0.cv2: <class 'models.common.Conv'>
# 12.cv2.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv2.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv2.1: <class 'models.common.Conv'>
# 12.cv2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv3: <class 'torch.nn.modules.container.Sequential'>
# 12.cv3.0: <class 'models.common.RepNCSP'>
# 12.cv3.0.cv1: <class 'models.common.Conv'>
# 12.cv3.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv3.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv3.0.cv2: <class 'models.common.Conv'>
# 12.cv3.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv3.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv3.0.cv3: <class 'models.common.Conv'>
# 12.cv3.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv3.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv3.0.m: <class 'torch.nn.modules.container.Sequential'>
# 12.cv3.0.m.0: <class 'models.common.RepNBottleneck'>
# 12.cv3.0.m.0.cv1: <class 'models.common.RepConvN'>
# 12.cv3.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 12.cv3.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv3.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv3.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 12.cv3.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 12.cv3.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv3.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv3.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 12.cv3.0.m.0.cv2: <class 'models.common.Conv'>
# 12.cv3.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv3.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv3.1: <class 'models.common.Conv'>
# 12.cv3.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv3.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 12.cv4: <class 'models.common.Conv'>
# 12.cv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 12.cv4.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 13: <class 'torch.nn.modules.upsampling.Upsample'>
# 14: <class 'models.common.Concat'>
# 15: <class 'models.common.RepNCSPELAN4'>
# 15.cv1: <class 'models.common.Conv'>
# 15.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv2: <class 'torch.nn.modules.container.Sequential'>
# 15.cv2.0: <class 'models.common.RepNCSP'>
# 15.cv2.0.cv1: <class 'models.common.Conv'>
# 15.cv2.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv2.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv2.0.cv2: <class 'models.common.Conv'>
# 15.cv2.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv2.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv2.0.cv3: <class 'models.common.Conv'>
# 15.cv2.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv2.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv2.0.m: <class 'torch.nn.modules.container.Sequential'>
# 15.cv2.0.m.0: <class 'models.common.RepNBottleneck'>
# 15.cv2.0.m.0.cv1: <class 'models.common.RepConvN'>
# 15.cv2.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 15.cv2.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv2.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv2.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 15.cv2.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 15.cv2.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv2.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv2.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 15.cv2.0.m.0.cv2: <class 'models.common.Conv'>
# 15.cv2.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv2.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv2.1: <class 'models.common.Conv'>
# 15.cv2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv3: <class 'torch.nn.modules.container.Sequential'>
# 15.cv3.0: <class 'models.common.RepNCSP'>
# 15.cv3.0.cv1: <class 'models.common.Conv'>
# 15.cv3.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv3.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv3.0.cv2: <class 'models.common.Conv'>
# 15.cv3.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv3.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv3.0.cv3: <class 'models.common.Conv'>
# 15.cv3.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv3.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv3.0.m: <class 'torch.nn.modules.container.Sequential'>
# 15.cv3.0.m.0: <class 'models.common.RepNBottleneck'>
# 15.cv3.0.m.0.cv1: <class 'models.common.RepConvN'>
# 15.cv3.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 15.cv3.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv3.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv3.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 15.cv3.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 15.cv3.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv3.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv3.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 15.cv3.0.m.0.cv2: <class 'models.common.Conv'>
# 15.cv3.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv3.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv3.1: <class 'models.common.Conv'>
# 15.cv3.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv3.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 15.cv4: <class 'models.common.Conv'>
# 15.cv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 15.cv4.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 16: <class 'models.common.ADown'>
# 16.cv1: <class 'models.common.Conv'>
# 16.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 16.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 16.cv2: <class 'models.common.Conv'>
# 16.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 16.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 17: <class 'models.common.Concat'>
# 18: <class 'models.common.RepNCSPELAN4'>
# 18.cv1: <class 'models.common.Conv'>
# 18.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv2: <class 'torch.nn.modules.container.Sequential'>
# 18.cv2.0: <class 'models.common.RepNCSP'>
# 18.cv2.0.cv1: <class 'models.common.Conv'>
# 18.cv2.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv2.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv2.0.cv2: <class 'models.common.Conv'>
# 18.cv2.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv2.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv2.0.cv3: <class 'models.common.Conv'>
# 18.cv2.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv2.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv2.0.m: <class 'torch.nn.modules.container.Sequential'>
# 18.cv2.0.m.0: <class 'models.common.RepNBottleneck'>
# 18.cv2.0.m.0.cv1: <class 'models.common.RepConvN'>
# 18.cv2.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 18.cv2.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv2.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv2.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 18.cv2.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 18.cv2.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv2.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv2.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 18.cv2.0.m.0.cv2: <class 'models.common.Conv'>
# 18.cv2.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv2.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv2.1: <class 'models.common.Conv'>
# 18.cv2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv3: <class 'torch.nn.modules.container.Sequential'>
# 18.cv3.0: <class 'models.common.RepNCSP'>
# 18.cv3.0.cv1: <class 'models.common.Conv'>
# 18.cv3.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv3.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv3.0.cv2: <class 'models.common.Conv'>
# 18.cv3.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv3.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv3.0.cv3: <class 'models.common.Conv'>
# 18.cv3.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv3.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv3.0.m: <class 'torch.nn.modules.container.Sequential'>
# 18.cv3.0.m.0: <class 'models.common.RepNBottleneck'>
# 18.cv3.0.m.0.cv1: <class 'models.common.RepConvN'>
# 18.cv3.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 18.cv3.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv3.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv3.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 18.cv3.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 18.cv3.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv3.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv3.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 18.cv3.0.m.0.cv2: <class 'models.common.Conv'>
# 18.cv3.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv3.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv3.1: <class 'models.common.Conv'>
# 18.cv3.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv3.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 18.cv4: <class 'models.common.Conv'>
# 18.cv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 18.cv4.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 19: <class 'models.common.ADown'>
# 19.cv1: <class 'models.common.Conv'>
# 19.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 19.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 19.cv2: <class 'models.common.Conv'>
# 19.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 19.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 20: <class 'models.common.Concat'>
# 21: <class 'models.common.RepNCSPELAN4'>
# 21.cv1: <class 'models.common.Conv'>
# 21.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv2: <class 'torch.nn.modules.container.Sequential'>
# 21.cv2.0: <class 'models.common.RepNCSP'>
# 21.cv2.0.cv1: <class 'models.common.Conv'>
# 21.cv2.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv2.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv2.0.cv2: <class 'models.common.Conv'>
# 21.cv2.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv2.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv2.0.cv3: <class 'models.common.Conv'>
# 21.cv2.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv2.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv2.0.m: <class 'torch.nn.modules.container.Sequential'>
# 21.cv2.0.m.0: <class 'models.common.RepNBottleneck'>
# 21.cv2.0.m.0.cv1: <class 'models.common.RepConvN'>
# 21.cv2.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 21.cv2.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv2.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv2.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 21.cv2.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 21.cv2.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv2.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv2.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 21.cv2.0.m.0.cv2: <class 'models.common.Conv'>
# 21.cv2.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv2.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv2.1: <class 'models.common.Conv'>
# 21.cv2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv3: <class 'torch.nn.modules.container.Sequential'>
# 21.cv3.0: <class 'models.common.RepNCSP'>
# 21.cv3.0.cv1: <class 'models.common.Conv'>
# 21.cv3.0.cv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv3.0.cv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv3.0.cv2: <class 'models.common.Conv'>
# 21.cv3.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv3.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv3.0.cv3: <class 'models.common.Conv'>
# 21.cv3.0.cv3.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv3.0.cv3.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv3.0.m: <class 'torch.nn.modules.container.Sequential'>
# 21.cv3.0.m.0: <class 'models.common.RepNBottleneck'>
# 21.cv3.0.m.0.cv1: <class 'models.common.RepConvN'>
# 21.cv3.0.m.0.cv1.conv1: <class 'models.common.Conv'>
# 21.cv3.0.m.0.cv1.conv1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv3.0.m.0.cv1.conv1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv3.0.m.0.cv1.conv1.act: <class 'torch.nn.modules.linear.Identity'>
# 21.cv3.0.m.0.cv1.conv2: <class 'models.common.Conv'>
# 21.cv3.0.m.0.cv1.conv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv3.0.m.0.cv1.conv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv3.0.m.0.cv1.conv2.act: <class 'torch.nn.modules.linear.Identity'>
# 21.cv3.0.m.0.cv2: <class 'models.common.Conv'>
# 21.cv3.0.m.0.cv2.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv3.0.m.0.cv2.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv3.1: <class 'models.common.Conv'>
# 21.cv3.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv3.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 21.cv4: <class 'models.common.Conv'>
# 21.cv4.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 21.cv4.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22: <class 'models.yolo.DDetect'>
# 22.cv2: <class 'torch.nn.modules.container.ModuleList'>
# 22.cv2.0: <class 'torch.nn.modules.container.Sequential'>
# 22.cv2.0.0: <class 'models.common.Conv'>
# 22.cv2.0.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv2.0.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv2.0.1: <class 'models.common.Conv'>
# 22.cv2.0.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv2.0.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv2.0.2: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv2.1: <class 'torch.nn.modules.container.Sequential'>
# 22.cv2.1.0: <class 'models.common.Conv'>
# 22.cv2.1.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv2.1.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv2.1.1: <class 'models.common.Conv'>
# 22.cv2.1.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv2.1.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv2.1.2: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv2.2: <class 'torch.nn.modules.container.Sequential'>
# 22.cv2.2.0: <class 'models.common.Conv'>
# 22.cv2.2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv2.2.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv2.2.1: <class 'models.common.Conv'>
# 22.cv2.2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv2.2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv2.2.2: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3: <class 'torch.nn.modules.container.ModuleList'>
# 22.cv3.0: <class 'torch.nn.modules.container.Sequential'>
# 22.cv3.0.0: <class 'models.common.Conv'>
# 22.cv3.0.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3.0.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv3.0.1: <class 'models.common.Conv'>
# 22.cv3.0.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3.0.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv3.0.2: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3.1: <class 'torch.nn.modules.container.Sequential'>
# 22.cv3.1.0: <class 'models.common.Conv'>
# 22.cv3.1.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3.1.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv3.1.1: <class 'models.common.Conv'>
# 22.cv3.1.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3.1.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv3.1.2: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3.2: <class 'torch.nn.modules.container.Sequential'>
# 22.cv3.2.0: <class 'models.common.Conv'>
# 22.cv3.2.0.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3.2.0.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv3.2.1: <class 'models.common.Conv'>
# 22.cv3.2.1.conv: <class 'torch.nn.modules.conv.Conv2d'>
# 22.cv3.2.1.bn: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# 22.cv3.2.2: <class 'torch.nn.modules.conv.Conv2d'>
# 22.dfl: <class 'models.common.DFL'>
# 22.dfl.conv: <class 'torch.nn.modules.conv.Conv2d'>
